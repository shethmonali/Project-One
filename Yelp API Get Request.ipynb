# %%
import numpy as np
import pandas as pd
import requests
import json
from census import Census
from us import states

# %%
client_id = "5v4lj6scMvX8paiEAY8P1A"
key = "tWK7hcKXRkkiHliqyI9MWEcGAhlO9wklZVlMk3aeY5ia7Cx834nkf8WTVVwQS3-F-dip_nXgpuOSbUB0sA-iY8IvO0g97y1gXMftPwhAWu9loX_9IChdZkDt8SykWnYx"

# %%
headers = {"Authorization": "Bearer tWK7hcKXRkkiHliqyI9MWEcGAhlO9wklZVlMk3aeY5ia7Cx834nkf8WTVVwQS3-F-dip_nXgpuOSbUB0sA-iY8IvO0g97y1gXMftPwhAWu9loX_9IChdZkDt8SykWnYx"}
url = "https://api.yelp.com/v3/businesses/search?term=food&location=%s" % ("94105")

# %%
response = requests.get(url, headers=headers)
yelp_data_json = response.json()
yelp_data_json
# Out:
# {'businesses': [{'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'coordinates': {'latitude': 37.789806, 'longitude': -122.410709},
#    'display_phone': '(415) 885-1325',
#    'distance': 509.81871816261395,
#    'id': 'tacorea-san-francisco',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rHxbA24tQgh8eIDrHGhCOA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '809 Bush St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'country': 'US',
#     'display_address': ['809 Bush St', 'San Francisco, CA 94108'],
#     'state': 'CA',
#     'zip_code': '94108'},
#    'name': 'Tacorea',
#    'phone': '+14158851325',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 965,
#    'transactions': [],
# ...
