# %%
import numpy as np
import pandas as pd
import requests
import json
from census import Census
from us import states

# %%
client_id = "5v4lj6scMvX8paiEAY8P1A"
key = "tWK7hcKXRkkiHliqyI9MWEcGAhlO9wklZVlMk3aeY5ia7Cx834nkf8WTVVwQS3-F-dip_nXgpuOSbUB0sA-iY8IvO0g97y1gXMftPwhAWu9loX_9IChdZkDt8SykWnYx"

# %%
headers = {"Authorization": "Bearer tWK7hcKXRkkiHliqyI9MWEcGAhlO9wklZVlMk3aeY5ia7Cx834nkf8WTVVwQS3-F-dip_nXgpuOSbUB0sA-iY8IvO0g97y1gXMftPwhAWu9loX_9IChdZkDt8SykWnYx"}
url = "https://api.yelp.com/v3/businesses/search?term=food&location=%s"

# %%
response = requests.get(url, headers=headers)
yelp_data_json = response.json()
yelp_data_json
# Out:
# {'businesses': [{'categories': [{'alias': 'comfortfood',
#      'title': 'Comfort Food'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'coordinates': {'latitude': 42.73292, 'longitude': -84.51292},
#    'display_phone': '',
#    'distance': 3464.7284869746777,
#    'id': 'streetkitchen-lansing',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/j1oGia1b25gA-ZESAAiz7g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '2722 E Michigan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Lansing',
#     'country': 'US',
#     'display_address': ['2722 E Michigan Ave', 'Lansing, MI 48912'],
#     'state': 'MI',
#     'zip_code': '48912'},
#    'name': 'StreetKitchen',
#    'phone': '',
#    'price': '$$',
#    'rating': 5.0,
#    'review_count': 23,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/streetkitchen-lansing?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'fishnchips', 'title': 'Fish & Chips'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'coordinates': {'latitude': 42.7358466, 'longitude': -84.4816632},
#    'display_phone': '(517) 664-0666',
#    'distance': 977.115331569784,
#    'id': 'crab-hero-east-lansing',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rWC6VAPKgE_IEbeAnEAZXg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '235 Albert Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'East Lansing',
#     'country': 'US',
#     'display_address': ['235 Albert Ave', 'East Lansing, MI 48823'],
#     'state': 'MI',
#     'zip_code': '48823'},
#    'name': 'Crab Hero',
#    'phone': '+15176640666',
#    'price': '$$$',
#    'rating': 4.0,
#    'review_count': 17,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/crab-hero-east-lansing?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'poke', 'title': 'Poke'},
#     {'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'coordinates': {'latitude': 42.7359142530297,
#     'longitude': -84.4809425981372},
#    'display_phone': '(517) 220-2988',
#    'distance': 969.968029253392,
#    'id': 'poké-lab-east-lansing-3',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uZLWWgcTtbkMm_YhYeI4zA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '245 Ann St',
#     'address2': None,
#     'address3': '',
#     'city': 'East Lansing',
#     'country': 'US',
#     'display_address': ['245 Ann St', 'East Lansing, MI 48823'],
#     'state': 'MI',
#     'zip_code': '48823'},
#    'name': 'Poké Lab',
#    'phone': '+15172202988',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 20,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/pok%C3%A9-lab-east-lansing-3?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 42.72945, 'longitude': -84.5089799},
#    'display_phone': '(517) 574-4214',
#    'distance': 3151.676207518734,
#    'id': 'green-dot-stables-lansing',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hvc_tm2UuSYDimyvjFQl1g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '410 S Clippert St',
#     'address2': None,
#     'address3': '',
#     'city': 'Lansing',
#     'country': 'US',
#     'display_address': ['410 S Clippert St', 'Lansing, MI 48912'],
#     'state': 'MI',
#     'zip_code': '48912'},
#    'name': 'Green Dot Stables',
#    'phone': '+15175744214',
#    'price': '$',
#    'rating': 3.5,
#    'review_count': 28,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/green-dot-stables-lansing?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'teppanyaki', 'title': 'Teppanyaki'}],
#    'coordinates': {'latitude': 42.73362, 'longitude': -84.47701},
#    'display_phone': '(517) 763-2278',
#    'distance': 575.0208849304059,
#    'id': 'hibachi-bowl-east-lansing-3',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uYUor00iQ8UNL9_Os41q1g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '547 E Grand River Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'East Lansing',
#     'country': 'US',
#     'display_address': ['547 E Grand River Ave', 'East Lansing, MI 48823'],
#     'state': 'MI',
#     'zip_code': '48823'},
#    'name': 'Hibachi Bowl',
#    'phone': '+15177632278',
#    'rating': 3.5,
#    'review_count': 9,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/hibachi-bowl-east-lansing-3?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'coordinates': {'latitude': 42.7259213672877,
#     'longitude': -84.4479211322941},
#    'display_phone': '(517) 889-1799',
#    'distance': 1953.71878245791,
#    'id': 'boiling-pots-east-lansing',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Js-PaC3M1YHuzoSMV7z-rA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '2650 E Grand River Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'East Lansing',
#     'country': 'US',
#     'display_address': ['2650 E Grand River Ave', 'East Lansing, MI 48823'],
#     'state': 'MI',
#     'zip_code': '48823'},
#    'name': 'Boiling Pots',
#    'phone': '+15178891799',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 50,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/boiling-pots-east-lansing?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'coordinates': {'latitude': 42.7338066527778,
#     'longitude': -84.4776740531113},
#    'display_phone': '(517) 351-0608',
#    'distance': 629.850431337108,
#    'id': 'peanut-barrel-east-lansing',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Jg6wv_gRqBSSnI9aAsjlXw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '521 E Grand River Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'East Lansing',
#     'country': 'US',
#     'display_address': ['521 E Grand River Ave', 'East Lansing, MI 48823'],
#     'state': 'MI',
#     'zip_code': '48823'},
#    'name': 'Peanut Barrel',
#    'phone': '+15173510608',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 189,
#    'transactions': ['delivery'],
#    'url': 'https://www.yelp.com/biz/peanut-barrel-east-lansing?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'coordinates': {'latitude': 42.7409884935827,
#     'longitude': -84.6118634801442},
#    'display_phone': '(517) 708-0404',
#    'distance': 11584.182354232742,
#    'id': 'choupli-wood-fired-kabob-lansing-2',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hHDXIidclun9zEH9gqy5yg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '4411 W Saginaw Hwy',
#     'address2': None,
#     'address3': '',
#     'city': 'Lansing',
#     'country': 'US',
#     'display_address': ['4411 W Saginaw Hwy', 'Lansing, MI 48917'],
#     'state': 'MI',
#     'zip_code': '48917'},
#    'name': 'Choupli Wood Fired Kabob',
#    'phone': '+15177080404',
#    'price': '$',
#    'rating': 5.0,
#    'review_count': 235,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/choupli-wood-fired-kabob-lansing-2?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'coordinates': {'latitude': 42.72038, 'longitude': -84.55202},
#    'display_phone': '(517) 253-7556',
#    'distance': 6785.633145144382,
#    'id': 'saddleback-bbq-lansing',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7rKqOYqKGwLRNFVtWke5Qg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1147 S Washington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Lansing',
#     'country': 'US',
#     'display_address': ['1147 S Washington Ave', 'Lansing, MI 48910'],
#     'state': 'MI',
#     'zip_code': '48910'},
#    'name': 'Saddleback BBQ',
#    'phone': '+15172537556',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 115,
#    'transactions': ['restaurant_reservation'],
#    'url': 'https://www.yelp.com/biz/saddleback-bbq-lansing?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'coordinates': {'latitude': 42.7195169255622,
#     'longitude': -84.4611632823944},
#    'display_phone': '(517) 483-2780',
#    'distance': 1565.675344633424,
#    'id': 'royal-pot-east-lansing',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lLG0N38oZ2J8cCMJhco-6w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '4750 Hagadorn Rd',
#     'address2': 'Ste 40',
#     'address3': None,
#     'city': 'East Lansing',
#     'country': 'US',
#     'display_address': ['4750 Hagadorn Rd',
#      'Ste 40',
#      'East Lansing, MI 48823'],
#     'state': 'MI',
#     'zip_code': '48823'},
#    'name': 'Royal Pot',
#    'phone': '+15174832780',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 20,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/royal-pot-east-lansing?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 42.730819, 'longitude': -84.466285},
#    'display_phone': '(517) 333-7104',
#    'distance': 356.51349171576,
#    'id': 'conrads-grill-east-lansing',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MiOL1_pZ2ztRal4-05JHxg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1219 E Grand River Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'East Lansing',
#     'country': 'US',
#     'display_address': ['1219 E Grand River Ave', 'East Lansing, MI 48823'],
#     'state': 'MI',
#     'zip_code': '48823'},
#    'name': "Conrad's Grill",
#    'phone': '+15173337104',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 20,
#    'transactions': ['delivery'],
#    'url': 'https://www.yelp.com/biz/conrads-grill-east-lansing?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'coordinates': {'latitude': 42.7337549, 'longitude': -84.5162594},
#    'display_phone': '(517) 648-7693',
#    'distance': 3743.456998357064,
#    'id': 'el-oasis-lansing',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LSoNFh6HBROesFgRByCcDA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '2501 E Michigan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Lansing',
#     'country': 'US',
#     'display_address': ['2501 E Michigan Ave', 'Lansing, MI 48912'],
#     'state': 'MI',
#     'zip_code': '48912'},
#    'name': 'El Oasis',
#    'phone': '+15176487693',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 166,
#    'transactions': ['delivery'],
#    'url': 'https://www.yelp.com/biz/el-oasis-lansing?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 42.736217, 'longitude': -84.487352},
#    'display_phone': '(517) 351-2506',
#    'distance': 1464.3351604156398,
#    'id': 'crunchys-east-lansing',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_MNLXYARN_5UfLopHKA22g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '254 W Grand River Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'East Lansing',
#     'country': 'US',
#     'display_address': ['254 W Grand River Ave', 'East Lansing, MI 48823'],
#     'state': 'MI',
#     'zip_code': '48823'},
#    'name': "Crunchy's",
#    'phone': '+15173512506',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 186,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/crunchys-east-lansing?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'burmese', 'title': 'Burmese'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'malaysian', 'title': 'Malaysian'}],
#    'coordinates': {'latitude': 42.698443, 'longitude': -84.548959},
#    'display_phone': '(857) 615-8393',
#    'distance': 7411.823895800517,
#    'id': 'naing-myanmar-family-restaurant-lansing',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TyHwga5c5LnQlX3zu1X1-g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3308 S Cedar St',
#     'address2': 'Ste 3',
#     'address3': '',
#     'city': 'Lansing',
#     'country': 'US',
#     'display_address': ['3308 S Cedar St', 'Ste 3', 'Lansing, MI 48910'],
#     'state': 'MI',
#     'zip_code': '48910'},
#    'name': 'Naing Myanmar Family Restaurant',
#    'phone': '+18576158393',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 183,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/naing-myanmar-family-restaurant-lansing?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 42.7337149, 'longitude': -84.530437},
#    'display_phone': '(517) 316-2377',
#    'distance': 4899.392606141544,
#    'id': 'soup-spoon-cafe-lansing',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LA4PYxMZKC91NOENc13udA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1419 E Michigan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Lansing',
#     'country': 'US',
#     'display_address': ['1419 E Michigan Ave', 'Lansing, MI 48912'],
#     'state': 'MI',
#     'zip_code': '48912'},
#    'name': 'Soup Spoon Cafe',
#    'phone': '+15173162377',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 421,
#    'transactions': ['restaurant_reservation'],
#    'url': 'https://www.yelp.com/biz/soup-spoon-cafe-lansing?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 42.7357827745332,
#     'longitude': -84.4818967913957},
#    'display_phone': '(517) 816-4300',
#    'distance': 1033.210084596652,
#    'id': 'hopcat-east-lansing',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/v0X1fr1jPL5TXiAT0bM-RQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '300 Grove St',
#     'address2': '',
#     'address3': '',
#     'city': 'East Lansing',
#     'country': 'US',
#     'display_address': ['300 Grove St', 'East Lansing, MI 48823'],
#     'state': 'MI',
#     'zip_code': '48823'},
#    'name': 'HopCat',
#    'phone': '+15178164300',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 332,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/hopcat-east-lansing?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'coordinates': {'latitude': 42.73389, 'longitude': -84.52141},
#    'display_phone': '(517) 999-7549',
#    'distance': 4168.776046348936,
#    'id': 'ruckus-ramen-lansing',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8mbAWlooC3WNBVLMenKwTw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '2021 E Michigan Ave',
#     'address2': None,
#     'address3': 'Avenue Cafe',
#     'city': 'Lansing',
#     'country': 'US',
#     'display_address': ['2021 E Michigan Ave',
#      'Avenue Cafe',
#      'Lansing, MI 48912'],
#     'state': 'MI',
#     'zip_code': '48912'},
#    'name': 'Ruckus Ramen',
#    'phone': '+15179997549',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 19,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/ruckus-ramen-lansing?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'coordinates': {'latitude': 42.7304, 'longitude': -84.462999},
#    'display_phone': '(517) 332-5555',
#    'distance': 628.708556326908,
#    'id': 'wings-over-east-lansing-east-lansing',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WjhjVgbZefPcUMuDWF8A3A/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1391 E Grand River Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'East Lansing',
#     'country': 'US',
#     'display_address': ['1391 E Grand River Ave', 'East Lansing, MI 48823'],
#     'state': 'MI',
#     'zip_code': '48823'},
#    'name': 'Wings Over East Lansing',
#    'phone': '+15173325555',
#    'price': '$$',
#    'rating': 3.5,
#    'review_count': 47,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/wings-over-east-lansing-east-lansing?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'coordinates': {'latitude': 42.71949, 'longitude': -84.46102},
#    'display_phone': '(517) 333-1933',
#    'distance': 1572.3338067061359,
#    'id': 'sansu-east-lansing',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7QqrIADTf-mg5fUcwOV3-Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '4750 S Hagadorn Rd',
#     'address2': 'Ste 100',
#     'address3': '',
#     'city': 'East Lansing',
#     'country': 'US',
#     'display_address': ['4750 S Hagadorn Rd',
#      'Ste 100',
#      'East Lansing, MI 48823'],
#     'state': 'MI',
#     'zip_code': '48823'},
#    'name': 'Sansu',
#    'phone': '+15173331933',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 252,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/sansu-east-lansing?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'},
#   {'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'coordinates': {'latitude': 42.7605583298988,
#     'longitude': -84.5045455131238},
#    'display_phone': '(517) 253-7898',
#    'distance': 4237.216446758662,
#    'id': 'glazed-and-confused-east-lansing',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZaIVzR_QhG8OHDXYJe3vfw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1595 W Lake Lansing Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'East Lansing',
#     'country': 'US',
#     'display_address': ['1595 W Lake Lansing Rd', 'East Lansing, MI 48823'],
#     'state': 'MI',
#     'zip_code': '48823'},
#    'name': 'Glazed and Confused',
#    'phone': '+15172537898',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 33,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/glazed-and-confused-east-lansing?adjust_creative=5v4lj6scMvX8paiEAY8P1A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5v4lj6scMvX8paiEAY8P1A'}],
#  'region': {'center': {'latitude': 42.7318368781,
#    'longitude': -84.4704437256}},
#  'total': 889}
